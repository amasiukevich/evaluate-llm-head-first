# %%
import os
from dotenv import load_dotenv


load_dotenv()

HUGGINGFACE_KEY = os.environ.get("HUGGINGFACE_KEY")
OPENAI_KEY = os.environ.get("OPENAI_API_KEY")

# %%
### importing from Trulens

from trulens_eval import Tru

tru = Tru()

# %%
### Simple LLM application

from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=['./eBook-How-to-Build-a-Career-in-AI.pdf']
).load_data()

# %%
from llama_index.core import Document

document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from llama_index.core import VectorStoreIndex, Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)
embedding_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

Settings.llm = llm
Settings.embed_model = embedding_model

index = VectorStoreIndex([document])
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
index = VectorStoreIndex.from_documents([document])

query_engine = index.as_query_engine()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
### Sanity checking for the request
response = query_engine.query("What did the author do in their youth?")
print(str(response))
# Out:
# The author has been privileged to see thousands of students, as well as engineers in companies large and small, navigate careers in AI.

# %%
### Initializing feedback functions

import numpy as np

# initializing provider class
from trulens_eval.feedback.provider.openai import OpenAI as fOpenAI()
openai = fOpenAI()


# select context to be used in feedback. the location of the context is app specific?
from trulens_eval.app import App

context = App.select_context(query_engine)


from trulens_eval import Feedback
from trulens_eval.feedback import Groundedness

grounded = Groundedness(groundedness_provider=fOpenAI())

f_groundedness = Feedback(grounded.groundedness_measure_with_cot_reasons) \
                    .on(context.collect()) \
                    .on_output() \
                    .aggregate(grounded.grounded_statements_aggregator)


# Question/answer relevance between overall question and answer.
f_qa_relevance = Feedback(openai.relevance).on_input_output()

# Question/statement relevance between question and each context chunk.
f_qs_relevance = Feedback(openai.qs_relevance)\
                    .on_input() \
                    .on(context) \
                    .aggregate(np.mean)
# Out:
# ✅ In groundedness_measure_with_cot_reasons, input source will be set to __record__.app.query.rets.source_nodes[:].node.text.collect() .
# ✅ In groundedness_measure_with_cot_reasons, input statement will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In qs_relevance, input question will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In qs_relevance, input statement will be set to __record__.app.query.rets.source_nodes[:].node.text .

# %%
### Instrumenting the app for logging in TruLens


from trulens_eval import TruLlama

tru_query_engine_recorder = TruLlama(
    query_engine,
    app_id="App1",
    feedbacks=[f_groundedness, f_qs_relevance, f_qa_relevance]
)

# %%
questions = []

with open("eval_questions.txt") as f:
    for line in f.readlines():
        questions.append(line.strip())

# %%
questions
# Out:
# ['What are the keys to building a career in AI?',
#  'How can teamwork contribute to success in AI?',
#  'What is the importance of networking in AI?',
#  'What are some good habits to develop for a successful career?',
#  'How can altruism be beneficial in building a career?',
#  'What is imposter syndrome and how does it relate to AI?',
#  'Who are some accomplished individuals who have experienced imposter syndrome?',
#  'What is the first step to becoming good at AI?',
#  'What are some common challenges in AI?',
#  'Is it normal to find parts of AI challenging?']

# %%
from tqdm import tqdm

with tru_query_engine_recorder as recorder:
    for question in tqdm(questions):
        response = query_engine.query(question)
# Out:
# 100%|██████████| 10/10 [00:26<00:00,  2.68s/it]

# %%
print(str(response))
# Out:
# It is normal to find parts of AI challenging.

# %%
rec = recorder.records

display(rec)
# Out:
# [Record(record_id='record_hash_8b46a05396b5529054dda2c6c40fd68a', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=984, n_stream_chunks=0, n_prompt_tokens=975, n_completion_tokens=9, cost=0.001464), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 13, 57, 92659), end_time=datetime.datetime(2024, 3, 11, 9, 13, 58, 544027)), ts=datetime.datetime(2024, 3, 11, 9, 13, 58, 546051), tags='-', meta=None, main_input='What are the keys to building a career in AI?', main_output='Job search, personal discipline, altruism.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='_retrieve'))], args={'query_bundle': {'query_str': 'What are the keys to building a career in AI?', 'image_path': None, 'custom_embedding_strs': None, 'embedding': [0.014841846190392971, -0.02138659544289112, 0.006421952974051237, -0.02859511412680149, -0.0017706004437059164, 0.013003209605813026, -0.020961785688996315, 0.016448164358735085, -0.005539141595363617, -0.02690914459526539, 0.03265737369656563, 0.021599002182483673, 0.010799501091241837, 0.007586865220218897, -0.010480892844498158, -0.010991993360221386, 0.028462359681725502, 0.00045675516594201326, 0.01014237105846405, -0.01252529677003622, -0.03143604099750519, 0.0074209230951964855, 0.006677503231912851, -0.01534631010144949, -0.015439237467944622, 0.0015266657574102283, 0.022315870970487595, -0.01534631010144949, -0.004088809248059988, -0.02811720035970211, 0.04795058071613312, -0.000169986771652475, -0.019620973616838455, -0.0022899985779076815, -0.01709865592420101, 0.02238224819302559, 0.002830969402566552, 0.007301445119082928, 0.016594193875789642, 0.005233808420598507, 0.03496728464961052, 0.014456860721111298, -0.002933853305876255, -0.017178308218717575, 0.002847563475370407, 0.019342191517353058, -0.02177158184349537, -0.002757954876869917, -0.019859930500388145, 0.004981576930731535, -0.0005824561812914908, 0.0222494937479496, -0.01942184381186962, -0.02065645158290863, -0.025608159601688385, 0.005091098602861166, -0.011503094807267189, 0.03594965860247612, 0.00018792923947330564, -0.007181966677308083, 0.01344129629433155, -0.0013391514075919986, 0.0027479983400553465, 0.0058942572213709354, -0.002326505957171321, -0.0032756938599050045, -0.01906340941786766, 0.015120629221200943, 0.0036341282539069653, -0.00941886380314827, 0.012717789970338345, 0.015067527070641518, -0.006528155412524939, 0.00430785259231925, 0.026258651167154312, -0.0017291149124503136, -0.008854661136865616, -0.02616572380065918, -0.012359355576336384, 0.0030018894467502832, -0.012883732095360756, 0.010228660888969898, -0.02629847824573517, -0.010613646358251572, 0.0012619884219020605, 0.014244455844163895, -0.0002294147270731628, -0.018744800239801407, -0.009259560145437717, -0.010374689474701881, 0.005711721256375313, -0.0005957315443083644, 0.030028851702809334, 0.016687121242284775, -0.02616572380065918, 0.015611817128956318, 0.023630131036043167, 0.0044439248740673065, -0.008861299604177475, -0.022674305364489555, 0.00482891034334898, 7.477758481400087e-05, -0.014470136724412441, -0.01590387523174286, -0.001654441119171679, 0.011277413927018642, 0.005754866171628237, 0.02041749469935894 ...
#  	selectors={'source': Lens().__record__.app.query.rets.source_nodes[:].node.text.collect(), 'statement': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f3770e61ed0 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f3770fe4bb0 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f3770e3b490 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f3770e61ed0 state=finished returned FeedbackResult>, <Future at 0x7f3770fe4bb0 state=finished returned FeedbackResult>, <Future at 0x7f3770e3b490 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_35fbec02ad23ca4fd846fab2fd773e71', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=1005, n_stream_chunks=0, n_prompt_tokens=928, n_completion_tokens=77, cost=0.0015325000000000002), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 13, 59, 8791), end_time=datetime.datetime(2024, 3, 11, 9, 14, 1, 762809)), ts=datetime.datetime(2024, 3, 11, 9, 14, 1, 764880), tags='-', meta=None, main_input='How can teamwork contribute to success in AI?', main_output='Teamwork in AI can contribute to success by enabling collaboration, influencing and being influenced by others, and fostering interpersonal and communication skills. Working in teams allows individuals to leverage diverse perspectives, share knowledge, and collectively tackle complex projects more effectively than working alone. Additionally, being part of a team helps in building a supportive network, which can provide assistance, guidance, and valuable insights when needed.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='_retrieve'))], args={'query_bundle': {'query_str': 'How can teamwork contribute to success in AI?', 'image_path': None, 'custom_embedding_strs': None, 'embedding': [-0.00549291493371129, -0.017788540571928024, 0.030612198635935783, -0.016389595344662666, -4.4734937546309084e-05, 0.024796977639198303, -0.00769419502466917, 0.028198333457112312, -0.008297661319375038, -0.04133744165301323, 0.012501352466642857, 0.012823658995330334, 0.008763976395130157, -0.010848677717149258, -0.004073397256433964, -0.011829311028122902, 0.02852749638259411, -1.1471699508547317e-05, -0.008846267126500607, -0.0043031261302530766, -0.02269856072962284, -0.001031207269988954, 0.007255310658365488, -0.00510889058932662, -0.015018081292510033, 0.005794648081064224, 0.018296001479029655, -0.03272433206439018, 0.021491628140211105, -0.005612922366708517, 0.05573834106326103, 0.006867857649922371, -0.02574332244694233, -0.0083662373945117, -0.013235112652182579, 0.0008079076651483774, 0.005146607290953398, 0.00905885174870491, 0.017719965428113937, -0.017226219177246094, 0.034671880304813385, 0.010066915303468704, 2.3492539185099304e-05, -0.016033001244068146, -0.03815552592277527, 0.016609037294983864, -0.019845811650156975, -0.01544325053691864, -0.012631646357476711, 0.0047968714497983456, 0.01632102020084858, 0.007138731889426708, -0.028637219220399857, -0.02619592286646366, -0.0030756208579987288, 0.010313787497580051, -0.02501642145216465, 0.02486555464565754, 0.015882136300206184, -0.016540462151169777, 0.013667140156030655, -0.0003651656734291464, 0.005143178626894951, 0.017212504521012306, -0.005160322412848473, -0.014935790561139584, -0.007118158973753452, 0.008098792284727097, 0.009381157346069813, 0.0004761726304423064, 0.011630441062152386, 0.009888618253171444, -0.01294709462672472, -0.0038059521466493607, 0.0176513884216547, -0.003836811287328601, -0.006771851796656847, -0.0178708303719759, -0.01382486429065466, 0.014579196460545063, -0.012521925382316113, -0.0009566312073729932, 0.0021378479432314634, -0.004642575979232788, 0.006631271447986364, 0.0017486807191744447, 0.021340763196349144, 0.002953898860141 ...
#  	selectors={'source': Lens().__record__.app.query.rets.source_nodes[:].node.text.collect(), 'statement': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f3770fbf400 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f3770fbf5b0 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f3770fbf0a0 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f3770fbf400 state=finished returned FeedbackResult>, <Future at 0x7f3770fbf5b0 state=finished returned FeedbackResult>, <Future at 0x7f3770fbf0a0 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_798612096281f1a51a99bd29ed75e4b3', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=1007, n_stream_chunks=0, n_prompt_tokens=928, n_completion_tokens=79, cost=0.0015365), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 14, 2, 136624), end_time=datetime.datetime(2024, 3, 11, 9, 14, 4, 344988)), ts=datetime.datetime(2024, 3, 11, 9, 14, 4, 346863), tags='-', meta=None, main_input='What is the importance of networking in AI?', main_output='Networking in AI is crucial as it helps in building a strong professional community that can provide support, advice, and opportunities. By connecting with others in the field, individuals can expand their knowledge, gain insights, and access resources that can propel their career forward. Additionally, networking allows for the exchange of ideas, collaboration on projects, and the establishment of valuable relationships that can lead to future career advancements.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='_retrieve'))], args={'query_bundle': {'query_str': 'What is the importance of networking in AI?', 'image_path': None, 'custom_embedding_strs': None, 'embedding': [-0.012178819626569748, -0.011002840474247932, 0.026263536885380745, -0.017382865771651268, 0.02242470718920231, 0.002698331605643034, -0.009840377606451511, 0.032116398215293884, -2.233473423984833e-05, -0.046471454203128815, 0.01040809229016304, 0.01071222499012947, 0.025925610214471817, -0.0020849977154284716, -0.008373782970011234, -0.010381057858467102, 0.0318460576236248, 0.0037509682588279247, 0.0037171756848692894, -0.0075492458418011665, -0.03527937829494476, 0.01308445818722248, 0.0026746769435703754, -0.027507100254297256, -0.0045045409351587296, 0.014747049659490585, 0.015030906535685062, -0.030359188094735146, 0.015260696411132812, -0.02222195267677307, 0.04382212087512016, 0.008326473645865917, -0.01221937034279108, 0.0022793046664446592, -0.00216778926551342, 0.0180046483874321, 0.015409382991492748, -0.006829465739428997, 0.017774857580661774, -0.005153357051312923, 0.03292741999030113, 0.010820360854268074, -0.006974773481488228, -0.00947541929781437, -0.02511459030210972, 0.017382865771651268, -0.0157473087310791, -0.01095553021878004, -0.009347007609903812, 0.005933964159339666, 0.015179594047367573, 0.012226128950715065, -0.023141108453273773, -0.028953419998288155, -0.04539009556174278, -0.00535949133336544, -0.03646887466311455, 0.020126817747950554, 0.0180046483874321, -0.014138785190880299, 0.019342830404639244, 0.0018078990979120135, -0.010029615834355354, 0.0014311126433312893, 0.0006348767201416194, -0.0073126982897520065, -0.012036890722811222, 0.015490485355257988, 0.004142961464822292, -0.003223805222660303, 0.028764180839061737, 0.03325182572007179, -0.017274729907512665, -0.01627447083592415, 0.0067213294096291065, 0.00954976212233305, -0.010124235413968563, 0.0018247953848913312, -0.01924821175634861, 0.01403064839541912, -0.009664656594395638, -0.0019261728739365935, 0.004061859101057053, -0.01908600702881813, 0.013091216795146465, 0.006035341881215572, 0.0055960388854146, -0.01017154473811388, 0.007576279807835817, -0.011989581 ...
#  	selectors={'source': Lens().__record__.app.query.rets.source_nodes[:].node.text.collect(), 'statement': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e88f340 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f376e88d480 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e88fd90 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f376e88f340 state=finished returned FeedbackResult>, <Future at 0x7f376e88d480 state=finished returned FeedbackResult>, <Future at 0x7f376e88fd90 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_b7455728de411bd5b0562a8324c6cd7d', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=671, n_stream_chunks=0, n_prompt_tokens=613, n_completion_tokens=58, cost=0.0010175), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 14, 4, 747855), end_time=datetime.datetime(2024, 3, 11, 9, 14, 7, 215190)), ts=datetime.datetime(2024, 3, 11, 9, 14, 7, 217140), tags='-', meta=None, main_input='What are some good habits to develop for a successful career?', main_output='Good habits to develop for a successful career include habits related to eating well, exercising regularly, getting enough sleep, maintaining positive personal relationships, staying dedicated to work, continuously learning, and taking care of oneself. These habits can help individuals progress in their careers while also ensuring their overall well-being.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name
Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e91c460 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f376e91e680 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e91d2a0 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f376e91c460 state=finished returned FeedbackResult>, <Future at 0x7f376e91e680 state=finished returned FeedbackResult>, <Future at 0x7f376e91d2a0 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_9a87740188fe756b9b5e993c4259518d', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=643, n_stream_chunks=0, n_prompt_tokens=614, n_completion_tokens=29, cost=0.0009609999999999999), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 14, 13, 360334), end_time=datetime.datetime(2024, 3, 11, 9, 14, 15, 607919)), ts=datetime.datetime(2024, 3, 11, 9, 14, 15, 611274), tags='-', meta=None, main_input='Who are some accomplished individuals who have experienced imposter syndrome?', main_output='Sheryl Sandberg, Michelle Obama, Tom Hanks, and Mike Cannon-Brookes are some accomplished individuals who have experienced imposter syndrome.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='_retrieve'))], args={'query_bundle': {'query_str': 'Who are some accomplished individuals who have experienced imposter syndrome?', 'image_path': None, 'custom_embedding_strs': None, 'embedding': [-0.017209725454449654, -0.02144334465265274, 0.0030097358394414186, -0.02503471076488495, -0.030723227187991142, 0.026175035163760185, -0.008709720335900784, 0.005688515491783619, 0.0010321902809664607, -0.0009502704488113523, 0.020381662994623184, -0.022531239315867424, 0.0011714540887624025, 0.0036634563002735376, 0.009620669297873974, -0.0011313133873045444, 0.030723227187991142, 0.012097925879061222, -0.015689292922616005, -0.019123373553156853, -0.023946814239025116, -0.014155752956867218, -0.005813033785670996, 0.006907483097165823, -0.01875637285411358, -0.024130316451191902, 0.028337720781564713, -0.021705487743020058, 0.02089284174144268, -0.01500771939754486, 0.02852122113108635, -0.01875637285411358, -0.004721860866993666, -0.018703943118453026, -0.018861230462789536, -0.002981883008033037, -0.01084619015455246, -0.012871249578893185, 0.020774878561496735, 0.011147655546665192, 0.002731208223849535, 0.017996156588196754, -0.015702400356531143, -0.017131082713603973, -0.007176180370151997, 0.0005562359001487494, -0.017511190846562386, -0.01994912512600422, -0.02654203586280346, 0.02122052200138569, 0.05347728729248047, -0.007412109524011612, -0.026660000905394554, -0.010715118609368801, -0.020198162645101547, -0.01651504449546337, 0.00585563201457262, 0.013035088777542114, -0.0069664656184613705, -0.00758905615657568, -0.005213380325585604, -0.008349272422492504, -0.009043953381478786, 0.00036822978290729225, 0.015990758314728737, -0.008984970860183239, -0.013828073628246784, 0.003088379045948386, 0.009463382884860039, 0.004518699832260609, 0.031037798151373863, 0.01080686878412962, -0.02565074898302555, 0.0021495772525668144, 0.026594465598464012, -0.02445799484848976, -0.04359447583556175, 0.008834238164126873, -0.0075104134157299995, -0.017288368195295334, 0.0005312503199093044, -0.015479577705264091, -0.016882045194506645, -0.012379730120301247, 0.0009551856201142073, 0.009201238863170147, 0.002657480537891388, -0.0007704563322477043, -0.011036244221031666, -0.008919434621930122, 0.02319970540702343, 0.03310873359441757, 0.021351594477891922, 0.03441945090889931, 0.005065924488008022, 0.012386283837258816, -0.012962999753654003, 0.020132625475525856, -0.0006295541534200311, -0.03853510320 ...
#  	selectors={'source': Lens().__record__.app.query.rets.source_nodes[:].node.text.collect(), 'statement': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e97cca0 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f376e898d00 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e89ae90 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f376e97cca0 state=finished returned FeedbackResult>, <Future at 0x7f376e898d00 state=finished returned FeedbackResult>, <Future at 0x7f376e89ae90 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_20857eab6a76502b0e0ce191fc9f670a', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=1114, n_stream_chunks=0, n_prompt_tokens=1103, n_completion_tokens=11, cost=0.0016600000000000002), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 14, 16, 176634), end_time=datetime.datetime(2024, 3, 11, 9, 14, 17, 387795)), ts=datetime.datetime(2024, 3, 11, 9, 14, 17, 391625), tags='-', meta=None, main_input='What is the first step to becoming good at AI?', main_output='Identify a business problem (not an AI problem).', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='query')), RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='retrieve')), RecordAppCallMethod(path=Lens().app._retriever, method=Method(obj=Obj(cls=llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, id=139879724834272, init_bindings=None), name='_retrieve'))], args={'query_bundle': {'query_str': 'What is the first step to becoming good at AI?', 'image_path': None, 'custom_embedding_strs': None, 'embedding': [0.012359777465462685, -0.020411856472492218, 0.011644036509096622, -0.01769469492137432, 0.009576342068612576, 0.018211618065834045, -0.006985096726566553, 0.008542494848370552, -0.011564509943127632, -0.03562796860933304, 0.018489962443709373, 0.027131864801049232, 0.010139656253159046, 0.010080011561512947, -0.008622021414339542, 0.005543674807995558, 0.03231435641646385, 0.01915268413722515, 0.005659651476889849, 0.0012856819666922092, -0.03210228309035301, 0.004122134763747454, 0.00025887603987939656, -0.025408785790205002, 0.0019964519888162613, -0.007415866479277611, 0.010583680123090744, -0.014977531507611275, -0.001174675882793963, -0.017071735113859177, 0.028523582965135574, -0.0031744414009153843, -0.007906281389296055, -0.013625577092170715, -0.002587931929156184, 0.008860602043569088, -0.00011090248881373554, 0.003635033732280135, 0.017230788245797157, -0.0016327828634530306, 0.037483591586351395, 0.0037874598056077957, 0.0005272786947898567, -0.0026525473222136497, -0.009112436324357986, 0.015494455583393574, -0.031810685992240906, 0.003558820579200983, -0.016700610518455505, 0.013758121989667416, 0.011040959507226944, 0.015335401520133018, -0.01624995842576027, -0.00925823487341404, -0.014831732958555222, 0.014447353780269623, -0.015401674434542656, 0.016581321135163307, 0.025448549538850784, 0.0015292324824258685, 0.013261079788208008, -0.0065278178080916405, 0.0037510101683437824, 0.02688002958893776, -0.013274334371089935, 0.016713865101337433, -0.012300131842494011, 0.014884750358760357, -0.0012583446223288774, 0.0015515993582084775, 0.00971551425755024, 0.010285455733537674, -0.02277114987373352, -0.0016775167314335704, 0.03265897184610367, -0.0011920722899958491, -0.011345811188220978, -0.01225374173372984, -0.019603336229920387, 0.005696101114153862, -0.00153171771671623, 0.007899654097855091, -0.015401674434542656, 0.022201208397746086, 0.003103198716416955, 0.006295864935964346, 0.01103433221578598, 0.006289237644523382, 0.012054924853146076, -0.007250185590237379, 0.026363106444478035, 0.010656580328941345, 0.03318915143609047, 0.010159538127481937, -0.018251381814479828, -0.0018340848619118333, 0.0017744398210197687, -0.01851646974682808, -0.01508356723934412, -0.030829858034849167, 0.012074806727468967, -0.016435520723462105, -0.0283910371363163, -0.012777292169630527, 0.008754566311836243, 0.004016099032014608, -0.00392663152 ...
#  	selectors={'source': Lens().__record__.app.query.rets.source_nodes[:].node.text.collect(), 'statement': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e97ca30 state=finished returned FeedbackResult>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f376ea5c0d0 state=finished returned FeedbackResult>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376ea5c1f0 state=finished returned FeedbackResult>)], feedback_results=[<Future at 0x7f376e97ca30 state=finished returned FeedbackResult>, <Future at 0x7f376ea5c0d0 state=finished returned FeedbackResult>, <Future at 0x7f376ea5c1f0 state=finished returned FeedbackResult>]),
#  Record(record_id='record_hash_87f45b540f3c01967e004a2798b6f72e', app_id='App1', cost=Cost(n_requests=2, n_successful_requests=2, n_classes=0, n_tokens=1025, n_stream_chunks=0, n_prompt_tokens=926, n_completion_tokens=99, cost=0.0015750000000000002), perf=Perf(start_time=datetime.datetime(2024, 3, 11, 9, 14, 17, 745918), end_time=datetime.datetime(2024, 3, 11, 9, 14, 20, 628115)), ts=datetime.datetime(2024, 3, 11, 9, 14, 20, 630142), tags='-', meta=None, main_input='What are some common challenges in AI?', main_output='Common challenges in AI include the evolving nature of technologies, the need to constantly keep up-to-date with changing technology, the difficulty in estimating project timelines and return on investment, setting expectations due to the iterative nature of AI projects, challenges in project management when the timeline for achieving target accuracy is uncertain, the necessity for further iteration post-deployment, collaborating with stakeholders lacking AI expertise, uncertainties in the required AI skills for different job roles, and the importance of building a supportive community throughout the career journey.', main_error=None, calls=[RecordAppCall(stack=[RecordAppCallMethod(path=Lens().app, method=Method(obj=Obj(cls=llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine, id=139876085465152, init_bindings=None), name
Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376e88f010 state=running>), (FeedbackDefinition(qs_relevance,
#  	selectors={'question': Lens().__record__.main_input, 'statement': Lens().__record__.app.query.rets.source_nodes[:].node.text},
#  	if_exists=None
#  ), <Future at 0x7f376e91df00 state=running>), (FeedbackDefinition(relevance,
#  	selectors={'prompt': Lens().__record__.main_input, 'response': Lens().__record__.main_output},
#  	if_exists=None
#  ), <Future at 0x7f376ea5e200 state=running>)], feedback_results=[<Future at 0x7f376e88f010 state=running>, <Future at 0x7f376e91df00 state=running>, <Future at 0x7f376ea5e200 state=running>])]

# %%
# recs = recording.records # use .records if multiple

# %%
records, feedback = tru.get_records_and_feedback(app_ids=["App1"])

records.head()
# Out:
#   app_id                                           app_json  \
# 0   App1  {"tru_class_info": {"name": "TruLlama", "modul...
# 1   App1  {"tru_class_info": {"name": "TruLlama", "modul...
# 2   App1  {"tru_class_info": {"name": "TruLlama", "modul...
# 3   App1  {"tru_class_info": {"name": "TruLlama", "modul...
# 4   App1  {"tru_class_info": {"name": "TruLlama", "modul...
#
#                                                 type  \
# 0  RetrieverQueryEngine(llama_index.core.query_en...
# 1  RetrieverQueryEngine(llama_index.core.query_en...
# 2  RetrieverQueryEngine(llama_index.core.query_en...
# 3  RetrieverQueryEngine(llama_index.core.query_en...
# 4  RetrieverQueryEngine(llama_index.core.query_en...
#
#                                       record_id  \
# 0  record_hash_1a0f573839fd2911f50b30a169eb48ba
# 1  record_hash_0eca43e15d4b10b7ed55f28a707e56a2
# 2  record_hash_2d908d0cf41936b8fd4692664019d260
# 3  record_hash_4907bf81ea1fef087961f882ae612bc4
# 4  record_hash_29778fb4631c49b9f722b33b5072d528
#
#                                              input  \
# 0          "What did author do when he was young?"
# 1          "What did author do when he was young?"
# 2          "What did author do when he was young?"
# 3          "What did author do when he was young?"
# 4  "What are the keys to building a career in AI?"
#
#                                               output tags  \
# 0  "The author, when he was young, worked on writ...    -
# 1  "When the author was young, they worked on wri...    -
# 2  "The author, when he was young, worked on writ...    -
# 3  "When the author was young, they worked on wri...    -
# 4  "The keys to building a career in AI involve u...    -
#
#                                          record_json  \
# 0  {"record_id": "record_hash_1a0f573839fd2911f50...
# 1  {"record_id": "record_hash_0eca43e15d4b10b7ed5...
# 2  {"record_id": "record_hash_2d908d0cf41936b8fd4...
# 3  {"record_id": "record_hash_4907bf81ea1fef08796...
# 4  {"record_id": "record_hash_29778fb4631c49b9f72...
#
#                                            cost_json  \
# 0  {"n_requests": 2, "n_successful_requests": 2, ...
# 1  {"n_requests": 2, "n_successful_requests": 2, ...
# 2  {"n_requests": 2, "n_successful_requests": 2, ...
# 3  {"n_requests": 2, "n_successful_requests": 2, ...
# 4  {"n_requests": 2, "n_successful_requests": 2, ...
#
#                                            perf_json  \
# 0  {"start_time": "2024-03-08T16:26:38.865500", "...
# 1  {"start_time": "2024-03-08T16:27:57.234683", "...
# 2  {"start_time": "2024-03-08T16:34:13.961058", "...
# 3  {"start_time": "2024-03-08T16:36:52.575770", "...
# 4  {"start_time": "2024-03-08T16:38:49.583678", "...
#
#                            ts  relevance  qs_relevance  \
# 0  2024-03-08T16:26:41.601896        1.0           0.5
# 1  2024-03-08T16:27:59.593466        1.0           0.5
# 2  2024-03-08T16:34:16.199118        1.0           0.5
# 3  2024-03-08T16:36:55.238265        1.0           0.5
# 4  2024-03-08T16:38:52.669274        1.0           0.2
#
#    groundedness_measure_with_cot_reasons  \
# 0                                   1.00
# 1                                   1.00
# 2                                   1.00
# 3                                   1.00
# 4                                   0.82
#
#                                      relevance_calls  \
# 0  [{'args': {'prompt': 'What did author do when ...
# 1  [{'args': {'prompt': 'What did author do when ...
# 2  [{'args': {'prompt': 'What did author do when ...
# 3  [{'args': {'prompt': 'What did author do when ...
# 4  [{'args': {'prompt': 'What are the keys to bui...
#
#                                   qs_relevance_calls  \
# 0  [{'args': {'question': 'What did author do whe...
# 1  [{'args': {'question': 'What did author do whe...
# 2  [{'args': {'question': 'What did author do whe...
# 3  [{'args': {'question': 'What did author do whe...
# 4  [{'args': {'question': 'What are the keys to b...
#
#          groundedness_measure_with_cot_reasons_calls  latency  total_tokens  \
# 0  [{'args': {'source': ['![](https://s.turbifycd...        2          2155
# 1  [{'args': {'source': ['![](https://s.turbifycd...        2          2171
# 2  [{'args': {'source': ['![](https://s.turbifycd...        2          2155
# 3  [{'args': {'source': ['![](https://s.turbifycd...        2          2171
# 4  [{'args': {'source': ['By which I mean the sor...        3          2178
#
#    total_cost
# 0    0.003252
# 1    0.003283
# 2    0.003252
# 3    0.003283
# 4    0.003286

# %%
tru.get_leaderboard()
# Out:
#                      Groundedness  qs_relevance  \
# app_id
# Direct Query Engine      0.507292           NaN
# App1                          NaN      0.429839
#
#                      groundedness_measure_with_cot_reasons  relevance  \
# app_id
# Direct Query Engine                                    NaN        NaN
# App1                                              0.659849   0.922581
#
#                        latency  total_cost
# app_id
# Direct Query Engine  10.294118    0.018749
# App1                  4.241935    0.002066

# %% [markdown]
# ### Sentence-Window Retrieval

# %%
### Utilities
from llama_index.core import ServiceContext, VectorStoreIndex, StorageContext
from llama_index.core.node_parser import SentenceWindowNodeParser
from llama_index.core import Settings

def build_sentence_window_index(
        document, llm, embed_model="BAAI/bge-small-en-v1.5", save_dir="sentence_index"
):
    
    node_parser = SentenceWindowNodeParser.from_defaults(
        window_size=3,
        window_metadata_key='window',
        original_text_metadata_key="original_text"
    )
    
    Settings.llm = llm
    Settings.embed_model = embed_model
    Settings.node_parser = node_parser

    if not os.path.exist(save_dir):
        sentence_index = VectorStoreIndex.from_documents(
            [document], 
        )

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

sentence_index = build_sentence_window_index(
    document, llm, embed_model="BAAI/bge-small-en-v1.5", save_dir="sentence_index"
)
